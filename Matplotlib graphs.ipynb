# %%
import matplotlib.pyplot as plt
# %matplotlib inline
y_views = [53,43,49,43,39]
days = range(1,6)
plt.plot(days,views,label='youtube views',color='c',marker='o',markerfacecolor='r',linestyle='-.',linewidth='3')
plt.xlabel('Day')
plt.ylabel('views')
plt.legend(loc='upper right')
plt.title('youtube views on daily basis')
plt.show()

# %% [markdown]
# ## Multi_variable graph drawn

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
y_views = [53,43,49,43,39]
f_views = [53,143,149,143,139]
r_views = [253,243,249,243,239]
days = range(1,6)
plt.plot(days,views,label='youtube views'
